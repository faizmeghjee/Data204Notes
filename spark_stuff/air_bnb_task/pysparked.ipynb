# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, LongType, StringType, FloatType, DateType, DoubleType
from pyspark.sql.functions import desc, asc, col, avg, round, sum, max, min, mean, count, filter, isnan, when
import pyspark.ml.feature as MF

# %%
spark = SparkSession.builder.getOrCreate()

# %%
df = spark.read.csv('listings.csv', header=True, inferSchema=True)

# %% [markdown]
# Casting columns data type

# %%
df = df.withColumn('reviews_per_month', col('reviews_per_month').cast(DoubleType()))
df = df.withColumn('longitude', col('longitude').cast(DoubleType()))

# %%
numeric_cols = [c for c,t in df.dtypes if t in ('double')]
string_cols = [c for c,t in df.dtypes if t in ('string')]

print(string_cols)
# Out:
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country', 'latitude', 'is_location_exact', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'requires_license', 'license', 'jurisdiction_names', 'instant_bookable', 'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count']

# %% [markdown]
# Counts number of missing values per column

# %%
df[string_cols].select([count(when(col(c).isNull(), c)).alias(c) for c in df[string_cols].columns]).show()
df[numeric_cols].select([count(when(col(c).isNull(), c)).alias(c) for c in df[numeric_cols].columns]).show()
# Out:
# +---+-----------+---------+------------+----+-------+-----+-----------+-------------------+---------------------+-----+-------+-------------+----------+-----------+--------------+-------+--------+---------+----------+-------------+----------+------------------+------------------+--------------------+-----------------+------------------+----------------+------------------+-------------------+-------------------------+------------------+--------------------+----------------------+------+-------------+----------------------+----------------------------+----+-----+-------+------+--------------+------------+-------+--------+-----------------+-------------+---------+------------+---------+--------+----+--------+---------+-----------+-----+------------+-------------+----------------+------------+---------------+------------+--------------+--------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+----------------+-------+------------------+----------------+-------------------+-----------------------------+--------------------------------+------------------------------+
# | id|listing_url|scrape_id|last_scraped|name|summary|space|description|experiences_offered|neighborhood_overview|notes|transit|thumbnail_url|medium_url|picture_url|xl_picture_url|host_id|host_url|host_name|host_since|host_location|host_about|host_response_time|host_response_rate|host_acceptance_rate|host_is_superhost|host_thumbnail_url|host_picture_url|host_neighbourhood|host_listings_count|host_total_listings_count|host_verifications|host_has_profile_pic|host_identity_verified|street|neighbourhood|neighbourhood_cleansed|neighbourhood_group_cleansed|city|state|zipcode|market|smart_location|country_code|country|latitude|is_location_exact|property_type|room_type|accommodates|bathrooms|bedrooms|beds|bed_type|amenities|square_feet|price|weekly_price|monthly_price|security_deposit|cleaning_fee|guests_included|extra_people|minimum_nights|maximum_nights|calendar_updated|has_availability|availability_30|availability_60|availability_90|availability_365|calendar_last_scraped|number_of_reviews|first_review|last_review|review_scores_rating|review_scores_accuracy|review_scores_cleanliness|review_scores_checkin|review_scores_communication|review_scores_location|review_scores_value|requires_license|license|jurisdiction_names|instant_bookable|cancellation_policy|require_guest_profile_picture|require_guest_phone_verification|calculated_host_listings_count|
# +---+-----------+---------+------------+----+-------+-----+-----------+-------------------+---------------------+-----+-------+-------------+----------+-----------+--------------+-------+--------+---------+----------+-------------+----------+------------------+------------------+--------------------+-----------------+------------------+----------------+------------------+-------------------+-------------------------+------------------+--------------------+----------------------+------+-------------+----------------------+----------------------------+----+-----+-------+------+--------------+------------+-------+--------+-----------------+-------------+---------+------------+---------+--------+----+--------+---------+-----------+-----+------------+-------------+----------------+------------+---------------+------------+--------------+--------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+----------------+-------+------------------+----------------+-------------------+-----------------------------+--------------------------------+------------------------------+
# |  0|       1247|     1742|        2038|2247|   2629| 3129|       2662|               2702|                 3701| 4207|   3670|         3038|      3042|       2810|          3066|   2790|    2791|     2793|      2798|         2794|      3568|              3813|              3837|                3858|             3880|              3896|            3917|              4138|               3942|                     3952|              3967|                3982|                  3986|  3985|         4281|                  4016|                        4033|4036| 4046|   4066|  4077|          4099|        4135|   4174|    4215|             4257|         4283|     4275|        4293|     4274|    4250|4220|    4217|     4193|       4228| 4160|        4205|         4214|            4228|        4218|           4235|        4301|          4355|          4451|            4560|            4643|           4725|           4788|           4791|            4788|                 4734|             4714|        4649|       4595|                4533|                  4515|                     4547|                 4552|                       4608|                  4693|               4805|            4884|   5051|              5113|            5233|               5345|                         5444|                            5499|                          5566|
# +---+-----------+---------+------------+----+-------+-----+-----------+-------------------+---------------------+-----+-------+-------------+----------+-----------+--------------+-------+--------+---------+----------+-------------+----------+------------------+------------------+--------------------+-----------------+------------------+----------------+------------------+-------------------+-------------------------+------------------+--------------------+----------------------+------+-------------+----------------------+----------------------------+----+-----+-------+------+--------------+------------+-------+--------+-----------------+-------------+---------+------------+---------+--------+----+--------+---------+-----------+-----+------------+-------------+----------------+------------+---------------+------------+--------------+--------------+----------------+----------------+---------------+---------------+---------------+----------------+---------------------+-----------------+------------+-----------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+-------------------+----------------+-------+------------------+----------------+-------------------+-----------------------------+--------------------------------+------------------------------+
#
# +---------+-----------------+
# |longitude|reviews_per_month|
# +---------+-----------------+
# |     5541|             6398|
# +---------+-----------------+

# %% [markdown]
# Check specific column for missing values

# %%
df.select([count(when(col('host_name').isNull(),True))]).show()
# Out:
# +--------------------------------------------------+
# |count(CASE WHEN (host_name IS NULL) THEN true END)|
# +--------------------------------------------------+
# |                                              2793|
# +--------------------------------------------------+

# %% [markdown]
# Drop specific rows with missing values in specificed column

# %%
df = df.dropna(subset=['host_name'], how='any')
df.select([count(when(col('host_name').isNull(),True))]).show()
# Out:
# +--------------------------------------------------+
# |count(CASE WHEN (host_name IS NULL) THEN true END)|
# +--------------------------------------------------+
# |                                                 0|
# +--------------------------------------------------+

# %% [markdown]
# Replace null values in numeric columns with the mean

# %%
imputer = MF.Imputer(strategy='mean', inputCols=[c for c in df[numeric_cols].columns],  outputCols=[c for c in df[numeric_cols].columns])
model = imputer.fit(df)
df1 = model.transform(df)

# %%
df1.select([count(when(col('longitude').isNull(),True))]).show()
df1[numeric_cols].orderBy(asc('longitude')).show()
# Out:
# +--------------------------------------------------+
# |count(CASE WHEN (longitude IS NULL) THEN true END)|
# +--------------------------------------------------+
# |                                                 0|
# +--------------------------------------------------+
#
# +-------------------+-----------------+
# |          longitude|reviews_per_month|
# +-------------------+-----------------+
# | -122.4172188142562|99.97435318275154|
# |-122.41636191405388|            100.0|
# |-122.41584774912927|            100.0|
# |-122.41545457464815|             10.0|
# |-122.41541701923138|            365.0|
# |-122.41502502060048|             10.0|
# |-122.41380164048266|99.97435318275154|
# |-122.41366735523944|             10.0|
# | -122.4129798367683|             10.0|
# |-122.41297509483515|99.97435318275154|
# |-122.41166700268097|             10.0|
# |-122.41147001291664|99.97435318275154|
# |-122.41136943694207|99.97435318275154|
# |-122.41108586541058|99.97435318275154|
# |-122.41048671948457|99.97435318275154|
# | -122.4101447891087|             10.0|
# | -122.4097418910164|99.97435318275154|
# |-122.40968312954868|99.97435318275154|
# |-122.40876488885866|             60.0|
# | -122.4085242090064|99.97435318275154|
# +-------------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# Replace all missing values for string cols

# %%
df.fillna('Missing_Data', subset=string_cols).show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------+--------------------+--------------------+-----------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+-----------------+--------------------+---------------+----------------+---------------------+--------------------+------------+--------------------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+--------------------+--------------------+------------+--------------------+----------------+-------------------+-----------------------------+--------------------------------+------------------------------+-----------------+
# |                  id|         listing_url|           scrape_id|        last_scraped|                name|             summary|               space|         description| experiences_offered|neighborhood_overview|               notes|             transit|       thumbnail_url|          medium_url|         picture_url|      xl_picture_url|             host_id|            host_url|           host_name|          host_since|       host_location|          host_about|  host_response_time|  host_response_rate|host_acceptance_rate|   host_is_superhost|  host_thumbnail_url|    host_picture_url|  host_neighbourhood| host_listings_count|host_total_listings_count|  host_verifications|host_has_profile_pic|host_identity_verified|              street|       neighbourhood|neighbourhood_cleansed|neighbourhood_group_cleansed|                city|               state|             zipcode|              market|      smart_location|        country_code|             country|            latitude|          longitude|  is_location_exact|property_type|           room_type|        accommodates|        bathrooms|          bedrooms|                beds|            bed_type|           amenities|         square_feet|               price|        weekly_price|       monthly_price|    security_deposit|        cleaning_fee|     guests_included|        extra_people|      minimum_nights|      maximum_nights| calendar_updated|    has_availability|  availability_30|     availability_60|availability_90|availability_365|calendar_last_scraped|   number_of_reviews|first_review|         last_review|review_scores_rating|review_scores_accuracy|review_scores_cleanliness|review_scores_checkin|review_scores_communication|review_scores_location| review_scores_value|    requires_license|     license|  jurisdiction_names|instant_bookable|cancellation_policy|require_guest_profile_picture|require_guest_phone_verification|calculated_host_listings_count|reviews_per_month|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------+--------------------+--------------------+-----------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+-----------------+--------------------+---------------+----------------+---------------------+--------------------+------------+--------------------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+--------------------+--------------------+------------+--------------------+----------------+-------------------+-----------------------------+--------------------------------+------------------------------+-----------------+
# |              241032|https://www.airbn...|      20160104002432|          2016-01-04|Stylish Queen Ann...|        Missing_Data|Make your self at...|Make your self at...|                none|         Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|https://a1.muscac...|        Missing_Data|              956883|https://www.airbn...|               Maija|          2011-08-11|Seattle, Washingt...|I am an artist, i...|  within a few hours|                 96%|                100%|                   f|https://a0.muscac...|https://a0.muscac...|          Queen Anne|                   3|                        3|['email', 'phone'...|                   t|                     t|Gilman Dr W, Seat...|          Queen Anne|       West Queen Anne|                  Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|  47.636289038357184|-122.37102519997765|                  t|    Apartment|     Entire home/apt|                   4|              1.0|                 1|                   1|            Real Bed|   "{TV,""Cable TV""|            Internet|""Wireless Intern...|""Air Conditioning""|             Kitchen|             Heating|""Family/Kid Frie...|              Washer|             Dryer}"|        Missing_Data|              $85.00|     Missing_Data|        Missing_Data|     Missing_Data|        Missing_Data|              2|           $5.00|                    1|                 365| 4 weeks ago|                   t|                  14|                    41|                       71|                  346|                 2016-01-04|                   207|          2011-11-01|          2016-01-02|          95|                  10|              10|                 10|                           10|                               9|                            10|             null|
# |              953595|https://www.airbn...|      20160104002432|          2016-01-04|Bright & Airy Que...|Chemically sensit...|Beautiful, hypoal...|Chemically sensit...|                none| Queen Anne is a w...|What's up with th...|Convenient bus st...|https://a0.muscac...|https://a0.muscac...|https://a0.muscac...|https://a0.muscac...|             5177328|https://www.airbn...|              Andrea|          2013-02-21|Seattle, Washingt...|Living east coast...|      within an hour|                 98%|                100%|                   t|https://a0.muscac...|https://a0.muscac...|          Queen Anne|                   6|                        6|['email', 'phone'...|                   t|                     t|7th Avenue West, ...|          Queen Anne|       West Queen Anne|                  Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47.63912312136253|-122.36566646439582|                  t|    Apartment|     Entire home/apt|                   4|              1.0|                 1|                   1|            Real Bed|"{TV,Internet,""W...|             Kitchen|""Free Parking on...|""Buzzer/Wireless...|             Heating|""Family/Kid Frie...|              Washer|               Dryer|  ""Smoke Detector""|""Carbon Monoxide...|   ""First Aid Kit""|  ""Safety Card""|""Fire Extinguish...|     Essentials}"|        Missing_Data|        $150.00|       $1,000.00|            $3,000.00|             $100.00|      $40.00|                   1|               $0.00|                     2|                       90|                today|                          t|                    13|                  13|                  16|         291|          2016-01-04|              43|         2013-08-19|                   2015-12-29|                              96|                            10|             10.0|
# |             3308979|https://www.airbn...|      20160104002432|          2016-01-04|New Modern House-...|New modern house ...|Our house is mode...|New modern house ...|                none| "Upper Queen Anne...|         restaurants| coffee shops and...| and situated on ...| the Space Needle...| Elliott Bay to t...| the Olympic Moun...| you'll love the ...|Our house is loca...|A bus stop is jus...|        Missing_Data|        Missing_Data|https://a2.muscac...|        Missing_Data|            16708587|https://www.airbn...|                Jill|          2014-06-12|Seattle, Washingt...|i love living in ...|  within a few hours|                      67%|                100%|                   f|  https://a1.muscac...|https://a1.muscac...|          Queen Anne|                     2|                           2|['email', 'phone'...|                   t|                   t|West Lee Street, ...|          Queen Anne|     West Queen Anne|          Queen Anne|             Seattle|               null|              98119|      Seattle|         Seattle, WA|                  US|    United States|47.629724131577355|  -122.3694831756176|                   t|               House|     Entire home/apt|                  11|                 4.5|                   5|                   7|            Real Bed|   "{TV,""Cable TV""|            Internet|""Wireless Intern...|""Air Conditioning""|          Kitchen|""Free Parking on...| ""Pets Allowed""|""Pets live on th...|         Dog(s)|          Cat(s)|          ""Hot Tub""|""Indoor Fireplace""|     Heating|""Family/Kid Frie...|              Washer|                 Dryer|       ""Smoke Detector""| ""Carbon Monoxide...|                 Essentials|             Shampoo}"|        Missing_Data|             $975.00|Missing_Data|        Missing_Data|       $1,000.00|            $300.00|                           10|                          $25.00|                             4|             30.0|
# |             7421966|https://www.airbn...|      20160104002432|          2016-01-04|  Queen Anne Chateau|A charming apartm...|        Missing_Data|A charming apartm...|                none|         Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|https://a0.muscac...|        Missing_Data|             9851441|https://www.airbn...|               Emily|          2013-11-06|Seattle, Washingt...|        Missing_Data|                 N/A|                 N/A|                 N/A|                   f|https://a2.muscac...|https://a2.muscac...|          Queen Anne|                   1|                        1|['email', 'phone'...|                   t|                     t|8th Avenue West, ...|          Queen Anne|       West Queen Anne|                  Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|  47.638473201766416|-122.36927912263018|                  t|    Apartment|     Entire home/apt|                   3|              1.0|                 0|                   2|            Real Bed|"{Internet,""Wire...|             Kitchen|""Indoor Fireplace""|             Heating|""Family/Kid Frie...|              Washer|               Dryer|  ""Smoke Detector""|""Carbon Monoxide...|     ""Safety Card""|""Fire Extinguish...|       Essentials|           Shampoo}"|     Missing_Data|             $100.00|        $650.00|       $2,300.00|         Missing_Data|        Missing_Data|           1|               $0.00|                   1|                  1125|             6 months ago|                    t|                          0|                     0|                   0|                 143|  2016-01-04|                   0|    Missing_Data|       Missing_Data|                 Missing_Data|                    Missing_Data|                  Missing_Data|             null|
# |              278830|https://www.airbn...|      20160104002432|          2016-01-04|Charming craftsma...|Cozy family craft...|Cozy family craft...|Cozy family craft...|                none| We are in the bea...|           Belltown |The nearest publi...|        Missing_Data|        Missing_Data|https://a1.muscac...|        Missing_Data|             1452570|https://www.airbn...|               Emily|          2011-11-29|Seattle, Washingt...|Hi, I live in Sea...|      within an hour|                100%|                 N/A|                   f|https://a0.muscac...|https://a0.muscac...|          Queen Anne|                   2|                        2|['email', 'phone'...|                   t|                     t|14th Ave W, Seatt...|          Queen Anne|       West Queen Anne|                  Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47.63291840276724|-122.37247063402224|                  t|        House|     Entire home/apt|                   6|              2.0|                 3|                   3|            Real Bed|   "{TV,""Cable TV""|            Internet|""Wireless Intern...|             Kitchen|             Heating|""Family/Kid Frie...|  ""Smoke Detector""|""Carbon Monoxide...|   ""First Aid Kit""|""Fire Extinguish...|          Essentials|        Shampoo}"|        Missing_Data|          $450.00|        Missing_Data|   Missing_Data|         $700.00|              $125.00|                   6|      $15.00|                   1|                1125|           7 weeks ago|                        t|                   30|                         60|                    90|                 365|          2016-01-04|          38|          2012-07-10|      2015-10-24|                 92|                            9|                               9|                            10|             10.0|
# |             5956968|https://www.airbn...|      20160104002432|          2016-01-04|Private unit in a...|We're renting out...|If you include a ...|We're renting out...|                none| This part of Quee...|Let me know if yo...|The #1 and #2 bus...|https://a2.muscac...|https://a2.muscac...|https://a2.muscac...|https://a2.muscac...|              326758|https://www.airbn...|              Andrew|          2010-12-25|Seattle, Washingt...|I've been fortuna...|                 N/A|                 N/A|                 N/A|                   f|https://a2.muscac...|https://a2.muscac...|          Queen Anne|                   1|                        1|['email', 'phone'...|                   t|                     t|West Comstock Str...|          Queen Anne|       West Queen Anne|                  Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47.63052548240193|-122.36617406518855|                  t|        House|        Private room|                   2|              1.0|                 1|                   1|            Real Bed|"{""Wireless Inte...|""Free Parking on...|             Heating|  ""Smoke Detector""|          Essentials|           Shampoo}"|        Missing_Data|             $120.00|             $800.00|        Missing_Data|        Missing_Data|           $40.00|                   1|           $30.00|                   1|              6|     2 weeks ago|                    t|                   0|           0|                  27|                 302|            2016-01-04|                       17|           2015-06-11|                 2015-09-28|                    95|                  10|                  10|          10|                  10|              10|                 10|                            f|                    Missing_Data|                    WASHINGTON|             null|
# |             1909058|https://www.airbn...|      20160104002432|          2016-01-04|Queen Anne Privat...|Enjoy a quiet sta...|Enjoy a quiet sta...|Enjoy a quiet sta...|                none| Close restaurants...|The room now has ...|The bus goes thro...|https://a2.muscac...|https://a2.muscac...|https://a2.muscac...|https://a2.muscac...|             2497928|https://www.airbn...|       Gary And Beth|          2012-05-30|Seattle, Washingt...|We have lived in ...|      within an hour|                100%|                100%|                   t|https://a0.muscac...|https://a0.muscac...|          Queen Anne|                   1|                        1|['email', 'phone'...|                   t|                     t|10th Avenue West,...|          Queen Anne|       West Queen Anne|                  Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47.63660544532006|-122.36851905844937|                  t|        House|        Private room|                   2|              1.0|                 1|                   1|            Real Bed|"{""Wireless Inte...|""Free Parking on...|             Heating|  ""Smoke Detector""|   ""First Aid Kit""|          Essentials|           Shampoo}"|        Missing_Data|              $80.00|             $575.00|        Missing_Data|          $150.00|        Missing_Data|                1|              $10.00|              3|              14|          5 weeks ago|                   t|          20|                  49|                  71|                   346|               2016-01-04|                   58|                 2014-01-27|            2015-12-07|                  99|                  10|          10|                  10|              10|                 10|                           10|                               f|                  Missing_Data|             null|
# |              856550|https://www.airbn...|      20160104002432|          2016-01-04|Tiny Garden cabin...|Our tiny cabin is...| This cabin was b...|Our tiny cabin is...|                none| We are centrally ...|There are three r...|"the ""D"" line r...|https://a2.muscac...|https://a2.muscac...|https://a2.muscac...|https://a2.muscac...|             4016632|https://www.airbn...|           Jean-Marc|          2012-10-30|Seattle, Washingt...|I am a carpenter ...|      within an hour|                100%|                100%|                   t|https://a1.muscac...|https://a1.muscac...|          Queen Anne|                   5|                        5|['email', 'phone'...|                   t|                     t|West Wheeler Stre...|          Queen Anne|       West Queen Anne|                  Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47
|https://a0.muscac...|https://a0.muscac...|https://a0.muscac...|https://a0.muscac...|              239585|https://www.airbn...|        Ray & Eileen|          2010-09-19|Seattle, Washingt...|"Eileen and Ray w...|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|             Missing_Data|        Missing_Data|        Missing_Data|          Missing_Data|        Missing_Data|        Missing_Data|          Missing_Data|                Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|               null|       Missing_Data| Missing_Data|        Missing_Data|        Missing_Data|     Missing_Data|      Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|     Missing_Data|        Missing_Data|     Missing_Data|        Missing_Data|   Missing_Data|    Missing_Data|         Missing_Data|        Missing_Data|Missing_Data|        Missing_Data|        Missing_Data|          Missing_Data|             Missing_Data|         Missing_Data|               Missing_Data|          Missing_Data|        Missing_Data|        Missing_Data|Missing_Data|        Missing_Data|    Missing_Data|       Missing_Data|                 Missing_Data|                    Missing_Data|                  Missing_Data|             null|
# |Eileen & Ray look...|  within a few hours|                100%|                100%|                   t|https://a2.muscac...|https://a2.muscac...|          Queen Anne|                   1|                    1|['email', 'phone'...|                   t|                   t|1st Ave W, Seattl...|          Queen Anne|     West Queen Anne|          Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47.63548170841016| -122.35847776162176|                   t|               House|     Entire home/apt|                   2|                      1.0|                   1|                   1|              Real Bed|   "{TV,""Cable TV""|            Internet|  ""Wireless Intern...|                     Kitchen|""Free Parking on...|             Heating|              Washer|               Dryer|  ""Smoke Detector""|""Carbon Monoxide...|   ""First Aid Kit""|     ""Safety Card""|               null|         Essentials|      Shampoo|""24-Hour Check-in""|             Hangers|   ""Hair Dryer""|              Iron|""Laptop Friendly...|        Missing_Data|              $95.00|             $595.00|        Missing_Data|        Missing_Data|              $15.00|                   2|              $15.00|                   3|                   7|          a week ago|                   t|                0|                   0|                0|                 153|     2016-01-04|             181|           2011-07-21|          2015-11-25|          97|                  10|                  10|                    10|                       10|                   10|                         10|                     f|        Missing_Data|          WASHINGTON|           f|            moderate|               t|                  f|                            1|                            3.33|                  Missing_Data|             null|
# |             4454295|https://www.airbn...|      20160104002432|          2016-01-04|Upper Queen Anne ...|Beautifully furni...|Beautiful home in...|Beautifully furni...|                none| I am located in t...|        Missing_Data|Yes, bus stops ju...|https://a0.muscac...|https://a0.muscac...|https://a0.muscac...|https://a0.muscac...|             4606439|https://www.airbn...|               Nadia|          2013-01-06|Seattle, Washingt...|My name is Nadia,...|  within a few hours|                100%|                100%|                   f|https://a1.muscac...|https://a1.muscac...|          Queen Anne|                   1|                        1|['email', 'phone'...|                   t|                     t|3rd Avenue West, ...|          Queen Anne|       West Queen Anne|                  Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47.63721407513561| -122.3600457614146|                  t|        House|     Entire home/apt|                   2|              1.0|                 1|                   1|            Real Bed|   "{TV,""Cable TV""|""Wireless Intern...|             Kitchen|""Free Parking on...|""Indoor Fireplace""|             Heating|  ""Smoke Detector""|""Carbon Monoxide...|""Fire Extinguish...|          Essentials|           Shampoo}"|     Missing_Data|              $99.00|          $800.00|           $2,000.00|        $500.00|         $150.00|                    1|               $0.00|           3|                1125|          a week ago|                     t|                       21|                   21|                         21|                   229|          2016-01-04|                   8|  2015-05-06|          2015-12-16|              97|                 10|                           10|                               9|                            10|             10.0|
# |             3883392|https://www.airbn...|      20160104002432|          2016-01-04|Open Plan 2bdr/1b...|Spacious apt in p...|This apartment is...|Spacious apt in p...|                none| "This neighborhoo...| yet in a quiet r...|                 gas|            eateries| great coffee sho...|           Key Arena|      Seattle Center| Music Project (EMP)| The Chihuly Glas...|            Belltown|      The Waterfront|    Cruise Terminals| Water Taxi to Al...| Myrtle Edwards Park| Seattle Sculptur...|            Magnolia| Trader Joes ***I...|    Downtown Seattle|  Seattle Art Museum| Ballard ***In
missing_Data|          Missing_Data|        Missing_Data|        Missing_Data|Missing_Data|        Missing_Data|    Missing_Data|       Missing_Data|                 Missing_Data|                    Missing_Data|                  Missing_Data|             null|
# | We have 3 kids u...| and my husband i...| so we dont reall...|       but if we did| we would spend e...|      within an hour|                100%|                100%|                   f| https://a2.muscac...|https://a2.muscac...|          Queen Anne|                   1|                   1|['email', 'phone'...|                   t|                   t|7th Avenue West, ...|          Queen Anne|     West Queen Anne|          Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47.63920265551509| -122.36586274154311|                        t|               House|     Entire home/apt|                    16|                 3.5|                   6|                    15|                    Real Bed|   "{TV,""Cable TV""|            Internet|""Wireless Intern...|             Kitchen|""Free Parking on...|""Indoor Fireplace""|             Heating|""Family/Kid Frie...|               null|             Washer|        Dryer|  ""Smoke Detector""|""Carbon Monoxide...|""First Aid Kit""|   ""Safety Card""|""Fire Extinguish...|          Essentials|           Shampoo}"|        Missing_Data|             $461.00|        Missing_Data|        Missing_Data|           $1,500.00|             $300.00|                   8|              $50.00|                   3|                  29|       5 days ago|                   t|               19|                  40|             65|             327|           2016-01-04|                  18|  2015-06-15|          2015-11-15|                  98|                     9|                       10|                   10|                         10|                    10|                  10|                   f|Missing_Data|          WASHINGTON|               t|             strict|                            f|                               f|                             1|             2.65|
# |             8988178|https://www.airbn...|      20160104002432|          2016-01-04|Lovely Queen Anne...|This home is full...|The Space This is...|This home is full...|                none| Queen Anne is a c...|        Missing_Data|You will be 2 blo...|        Missing_Data|        Missing_Data|https://a2.muscac...|        Missing_Data|             2983711|https://www.airbn...|               Paige|          2012-07-18|Seattle, Washingt...|I'm from Seattle....|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|             Missing_Data|        Missing_Data|        Missing_Data|          Missing_Data|        Missing_Data|        Missing_Data|          Missing_Data|                Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|               null|       Missing_Data| Missing_Data|        Missing_Data|        Missing_Data|     Missing_Data|      Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|        Missing_Data|     Missing_Data|        Missing_Data|     Missing_Data|        Missing_Data|   Missing_Data|    Missing_Data|         Missing_Data|        Missing_Data|Missing_Data|        Missing_Data|        Missing_Data|          Missing_Data|             Missing_Data|         Missing_Data|               Missing_Data|          Missing_Data|        Missing_Data|        Missing_Data|Missing_Data|        Missing_Data|    Missing_Data|       Missing_Data|                 Missing_Data|                    Missing_Data|                  Missing_Data|             null|
# |              Paige"|  within a few hours|                100%|                100%|                   f|https://a0.muscac...|https://a0.muscac...|        Missing_Data|                   1|                    1|['email', 'review...|                   t|                   f|12th Avenue West,...|        Missing_Data|     West Queen Anne|          Queen Anne|             Seattle|                  WA|               98119|             Seattle|         Seattle, WA|                  US|       United States|   47.63564979343857| -122.37289282480928|                   f|               House|     Entire home/apt|                   5|                      1.0|                   2|                   2|              Real Bed|   "{TV,""Cable TV""|            Internet|               Kitchen|        ""Free Parking on...|             Heating|""Family/Kid Frie...|              Washer|               Dryer|  ""Smoke Detector""|""Carbon Monoxide...|""Fire Extinguish...|        Essentials}"|               null|            $109.00| Missing_Data|        Missing_Data|        Missing_Data|           $89.00|                 1|               $0.00|                   3|                  15|          3 days ago|                   t|                  30|                  60|                  69|                  69|          2016-01-04|                   1|          2015-11-25|          2015-11-25|               80|                   8|               10|                   8|              8|               8|                    8|                   f|Missing_Data|          WASHINGTON|                   f|                strict|                        f|                    f|                          1|                  0.73|        Missing_Data|        Missing_Data|Missing_Data|        Missing_Data|    Missing_Data|       Missing_Data|                 Missing_Data|                    Missing_Data|                  Missing_Data|             null|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------------+--------------------+--------------------+----------------------+--------------------+--------------------+----------------------+----------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------+--------------------+--------------------+-----------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-----------------+--------------------+-----------------+--------------------+---------------+----------------+---------------------+--------------------+------------+--------------------+--------------------+----------------------+-------------------------+---------------------+---------------------------+----------------------+--------------------+--------------------+------------+--------------------+----------------+-------------------+-----------------------------+--------------------------------+------------------------------+-----------------+
# only showing top 20 rows
